# %%
import pandas as pd
from toolbox_ML import *
df = pd.read_csv('./data/CarPrice_Assignment.csv')
df = df.iloc[:, 1:]

# %%
describe_df(df)
# Out:
#                  DATA_TYPE MISSINGS (%) UNIQUE_VALUES CARDIN (%)
# symboling            int64            0             6       2.93
# CarName             object            0           147      71.71
# fueltype            object            0             2       0.98
# aspiration          object            0             2       0.98
# doornumber          object            0             2       0.98
# carbody             object            0             5       2.44
# drivewheel          object            0             3       1.46
# enginelocation      object            0             2       0.98
# wheelbase          float64            0            53      25.85
# carlength          float64            0            75      36.59
# carwidth           float64            0            44      21.46
# carheight          float64            0            49       23.9
# curbweight           int64            0           171      83.41
# enginetype          object            0             7       3.41
# cylindernumber      object            0             7       3.41
# enginesize           int64            0            44      21.46
# fuelsystem          object            0             8        3.9
# boreratio          float64            0            38      18.54
# stroke             float64            0            37      18.05
# compressionratio   float64            0            32      15.61
# horsepower           int64            0            59      28.78
# peakrpm              int64            0            23      11.22
# citympg              int64            0            29      14.15
# highwaympg           int64            0            30      14.63
# price              float64            0           189       92.2

# %%
tipifica_variables(df)
# Out:
#             variable               tipo
# 0          symboling         Categórica
# 1            CarName  Numérica Continua
# 2           fueltype            Binaria
# 3         aspiration            Binaria
# 4         doornumber            Binaria
# 5            carbody         Categórica
# 6         drivewheel         Categórica
# 7     enginelocation            Binaria
# 8          wheelbase  Numérica Continua
# 9          carlength  Numérica Continua
# 10          carwidth  Numérica Continua
# 11         carheight  Numérica Continua
# 12        curbweight  Numérica Continua
# 13        enginetype         Categórica
# 14    cylindernumber         Categórica
# 15        enginesize  Numérica Continua
# 16        fuelsystem         Categórica
# 17         boreratio  Numérica Continua
# 18            stroke  Numérica Continua
# 19  compressionratio  Numérica Continua
# 20        horsepower  Numérica Continua
# 21           peakrpm  Numérica Discreta
# 22           citympg  Numérica Discreta
# 23        highwaympg  Numérica Discreta
# 24             price  Numérica Continua

# %%
get_features_num_regression(df, 'price', 0.05)
# Out:
# ['wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg']

# %%
df.head()
# Out:
#    symboling                   CarName fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# 0         130        mpfi       3.47   2.68              9.0         111
# 1         130        mpfi       3.47   2.68              9.0         111
# 2         152        mpfi       2.68   3.47              9.0         154
# 3         109        mpfi       3.19   3.40             10.0         102
# 4         136        mpfi       3.19   3.40              8.0         115
#
#   peakrpm  citympg  highwaympg    price
# 0    5000       21          27  13495.0
# 1    5000       21          27  16500.0
# 2    5000       19          26  16500.0
# 3    5500       24          30  13950.0
# 4    5500       18          22  17450.0
#
# [5 rows x 25 columns]

# %%
plot_features_num_regression(df, 'price', umbral_corr=0.05, pvalue=0.05)

# %%
plot_features_num_regression(df, 'price', get_features_num_regression(df, 'price', 0.05), umbral_corr=0.05, pvalue=0.05)
# Out:
# ['wheelbase',
#  'carlength',
#  'carwidth',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'horsepower',
#  'citympg',
#  'highwaympg']

# %%
# Si la lista está vacía, entonces la función igualará "columns" a las variables NUMÉRICAS del dataframe

# %%
plot_features_num_regression(df, 'price', ['wheelbase',
 'carlength',
 'carwidth',
 'carheight',
 'curbweight',
 'enginesize',
 'boreratio',
 'stroke',
 'compressionratio',
 'horsepower'], umbral_corr=0.05)
# Out:
# ['wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower']

# %%
df.citympg.nunique()
# Out:
# 29

# %%
get_features_cat_regression(df, 'price', with_individual_plot=False)
# Out:
# ['CarName',
#  'aspiration',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %%
from toolbox import plot_features_cat_regression
plot_features_cat_regression(df, 'price')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 from toolbox import plot_features_cat_regression
# ----> 2 plot_features_cat_regression(df, 'price')
#
# File c:\Users\Eva\Documents\GitHub\Team-Challenge---Team-Lasso\toolbox.py:317, in plot_features_cat_regression(dataframe, target_col, columns, pvalue, with_individual_plot, size_group)
#     314      print(f"Existen nulos o NaN presentes en las variables numéricas de estudio, tenga en cuenta que el análisis de correlación se realizará eliminando esos nulos.")
#     316 for col in num_col: # Usamos la correlación de pearson para ver si están relacionadas (eliminando nulos en caso de que haya):
# --> 317     p = pearsonr(dataframe.dropna()[target_col], dataframe.dropna()[col]).pvalue
#     318     if p < pvalue: # Si la relación entre variables entra en la significación seleccionada, nos guardamos esa columna:
#     319         sig_num_col.append(col)
#
# File c:\Users\Eva\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py:4839, in pearsonr(x, y, alternative, method, axis)
#    4837 x = xp.astype(x, dtype, copy=False)
#    4838 y = xp.astype(y, dtype, copy=False)
# -> 4839 threshold = xp.finfo(dtype).eps ** 0.75
#    4841 # If an input is constant, the correlation coefficient is not defined.
#    4842 const_x = xp.all(x == x[..., 0:1], axis=-1)
#
# File c:\Users\Eva\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\_core\getlimits.py:522, in finfo.__new__(cls, dtype)
#     520     dtype = newdtype
#     521 if not issubclass(dtype, numeric.inexact):
# --> 522     raise ValueError("data type %r not inexact" % (dtype))
#     523 obj = cls._finfo_cache.get(dtype)
#     524 if obj is not None:
#
# ValueError: data type <class 'numpy.object_'> not inexact
